# %% [markdown]
# ## Challenge: Data cleaning & validation Unit 1.3.6
#
# Data cleaning is definitely a "practice makes perfect" skill. Using this dataset of article open-access prices paid by the [WELLCOME Trust between 2012 and 2013](https://www.dropbox.com/s/19cjdi7wqhlfcpt/WELLCOME.zip?dl=0), determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal . You will need to do considerable data cleaning in order to extract accurate estimates, and may want to look into data [encoding methods](https://stackoverflow.com/questions/2241348/what-is-unicode-utf-8-utf-16) if you get stuck. For a real bonus round, identify the open access prices paid by subject area.
#
# As noted in the previous assignment, don't modify the data directly. Instead, write a cleaning script that will load the raw data and whip it into shape. Jupyter notebooks are a great format for this. Keep a record of your decisions: well-commented code is a must for recording your data cleaning decision-making progress. Submit a link to your script and results below and discuss it with your mentor at your next session.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
apc_spend = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', 
                       index_col=None, encoding='latin-1')

apc_spend.head(5)
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
apc_spend.shape
# Out:
# (2127, 5)

# %%
apc_spend.dtypes
# Out:
# PMID/PMCID                                             object
# Publisher                                              object
# Journal title                                          object
# Article title                                          object
# COST (£) charged to Wellcome (inc VAT when charged)    object
# dtype: object

# %%
# Simplify column names
apc_spend = apc_spend.rename({'PMID/PMCID':'id', 'Publisher':'publisher',
                  'Journal title':'journal_title', 'Article title':'article_title', 
                  'COST (£) charged to Wellcome (inc VAT when charged)':'cost'}, axis='columns')

# %%
apc_spend.head(5)
# Out:
#                       id publisher           journal_title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        article_title      cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
# Check for unique items
apc_spend.nunique()
# Out:
# id               1880
# publisher         299
# journal_title     984
# article_title    2126
# cost             1402
# dtype: int64

# %%
# Verify there are no missing values as all columns have the 
# exact number of entries.
apc_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# id               1928 non-null object
# publisher        2127 non-null object
# journal_title    2126 non-null object
# article_title    2127 non-null object
# cost             2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB

# %%
# Check for missing values computation
apc_spend.isnull().sum()
# Out:
# id               199
# publisher          0
# journal_title      1
# article_title      0
# cost               0
# dtype: int64

# %%
# Since I am not going to focus on the ids and the readme file
# mentioned that the id data is not always accurate, I am removing
# the id column from the data
apc_spend = apc_spend.drop(columns=['id'])

# %%
# Now there is only one row with a null value, so I will remove that row
apc_spend = apc_spend.dropna()

apc_spend.isnull().sum()
# Out:
# publisher        0
# journal_title    0
# article_title    0
# cost             0
# dtype: int64

# %%
# Remove £ sterling character and $ from cost in row 179
#apc_spend['cost'] = apc_spend['cost'].apply(lambda x: x.strip('£'))
#apc_spend['cost'] = apc_spend['cost'].apply(lambda x: x.strip('$'))
apc_spend['cost'] = [x.strip('$') for x in apc_spend.cost] # quicker than lambda
apc_spend['cost'] = [x.strip('£') for x in apc_spend.cost]

apc_spend.head(5)
# Out:
#   publisher           journal_title  \
# 0       CUP  Psychological Medicine
# 1       ACS       Biomacromolecules
# 2       ACS              J Med Chem
# 3       ACS              J Med Chem
# 4       ACS              J Org Chem
#
#                                        article_title     cost
# 0  Reduced parahippocampal cortical thickness in ...     0.00
# 1  Structural characterization of a Model Gram-ne...  2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   669.64
# 4  Regioselective opening of myo-inositol orthoes...   685.88

# %%
#Change cost column from object to integer type
apc_spend['cost'] = pd.to_numeric(apc_spend['cost'],downcast='integer')

# Round cost column to whole number
apc_spend['cost'] = apc_spend['cost'].round()

apc_spend.head(5)
# Out:
#   publisher           journal_title  \
# 0       CUP  Psychological Medicine
# 1       ACS       Biomacromolecules
# 2       ACS              J Med Chem
# 3       ACS              J Med Chem
# 4       ACS              J Org Chem
#
#                                        article_title    cost
# 0  Reduced parahippocampal cortical thickness in ...     0.0
# 1  Structural characterization of a Model Gram-ne...  2381.0
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   643.0
# 3  Orvinols with mixed kappa/mu opioid receptor a...   670.0
# 4  Regioselective opening of myo-inositol orthoes...   686.0

# %%
# In case of extra whitespace, I am going to remove any that may be there
apc_spend['publisher'] = apc_spend['publisher'].str.strip()
apc_spend['journal_title'] = apc_spend['journal_title'].str.strip()
apc_spend['article_title'] = apc_spend['article_title'].str.strip()

apc_spend.tail(5)
# Out:
#                           publisher  \
# 2122          Wolters Kluwer Health
# 2123          Wolters Kluwer Health
# 2124          Wolters Kluwer Health
# 2125  Wolters Kluwer N.V./Lippinott
# 2126                Wolters Kluwers
#
#                                         journal_title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                             Pediatr Infect Dis J
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           article_title    cost
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...  1334.0
# 2123  Evaluation of an empiric risk screening score ...  1835.0
# 2124  Topical umbilical cord care for prevention of ...  1835.0
# 2125  Grassroots Community Organisations' Contributi...  2375.0
# 2126  A novel community health worker tool outperfor...  2035.0

# %% [markdown]
# Now I am going to clean journal titles, first by changing the text to lower case and the looking for typos and missing part to titles and correct those that have a lot that would affect whether the would be in the top 5 most common journals.  I went throught the alphabet and scanned for obvious errors that should be corrected.

# %%
# Making journal titles lower case
journal = apc_spend['journal_title'].str.lower().sort_values()
journal
# Out:
# 439                    academy of nutrition and dietetics
# 8                                    acs chemical biology
# 9                                    acs chemical biology
# 21                                   acs chemical biology
# 20                                   acs chemical biology
# 19                                   acs chemical biology
# 22                              acs chemical neuroscience
# 34                                               acs nano
# 23                                               acs nano
# 927     acta crystallographica section d,  biological ...
# 920     acta crystallographica section d: biological c...
# 928     acta crystallographica section f: structural b...
# 929     acta crystallographica section f: structural b...
# 921                     acta crystallographica, section d
# 922                                acta crystallography d
# 923                                                acta d
# 1711                           acta dermato venereologica
# 1716                                   acta diabetologica
# 924                                                acta f
# 1717                                     acta neuropathol
# 1718                                acta neuropathologica
# 1719                                acta neuropathologica
# 1720                                acta neuropathologica
# 2051                                  acta opthalmologica
# 1871                                         acta physiol
# 1873                                            addiction
# 1872                                            addiction
# 1722        advances in experimental medicine and biology
# 1723        advances in experimental medicine and biology
# 1721        advances in experimental medicine and biology
#                               ...
# 1795                  tropical animal health & production
# 954            tropical medicine and international health
# 2018           tropical medicine and international health
# 2006           tropical medicine and international health
# 2005           tropical medicine and international health
# 2004           tropical medicine and international health
# 955            tropical medicine and international health
# 816                                          tuberculosis
# 817                                          tuberculosis
# 371                                         urban history
# 1796                                         urolithiasis
# 818                                               vaccine
# 819                                               vaccine
# 843                                               vaccine
# 821                                               vaccine
# 820                                               vaccine
# 822                                 vascular pharmacology
# 823                               veterinary microbiology
# 824                               veterinary parasitology
# 825                               veterinary parasitology
# 328                                     veterinary record
# 243                                   veterinary research
# 1837                                             virology
# 826                                              virology
# 225                                      virology journal
# 827                                        virus research
# 828                                       vision research
# 829                                       vision research
# 372                                   visual neuroscience
# 2106                           zoonoses and public health
# Name: journal_title, Length: 2126, dtype: object

# %%
journal.value_counts().sort_values()
# Out:
# consciousness & cognition                                   1
# neuropsychobiology                                          1
# journal of acquired immune deficiency syndroms (jaids)      1
# international psychogeriatrics                              1
# international journal of parasitology                       1
# molecular & cellular proteomics                             1
# european child and adolescent psychiatry                    1
# child psychology psychiatry                                 1
# european journal of health law                              1
# computational biology                                       1
# american journal of public health                           1
# health & place                                              1
# journal of neuroendocrinology                               1
# mol bio                                                     1
# calcified tissue international                              1
# american chemical society                                   1
# metabolomics                                                1
# european journal of public health                           1
# plant biotechnology journal                                 1
# international journal of rheumatology                       1
# medical anthropology                                        1
# molecular and cellular biochemistry                         1
# bjp                                                         1
# molecluar & cellular endocrinology                          1
# chemical communication                                      1
# journal od clinical endocrinology                           1
# journal of chemical information and modeling                1
# autophagy                                                   1
# population, space and place                                 1
# economic history review                                     1
#                                                          ...
# european journal of immunology                              8
# journal of physiology                                       8
# hepatology                                                  8
# neuron                                                      9
# plosone                                                     9
# journal of virology                                         9
# plos computational biology                                  9
# development                                                 9
# bmj open                                                    9
# cell reports                                                9
# bmj                                                        10
# malaria journal                                            10
# current biology                                            11
# journal of general virology                                11
# developmental cell                                         12
# biochemical journal                                        12
# journal of neuroscience                                    13
# brain                                                      14
# bmc public health                                          14
# movement disorders                                         15
# nature communications                                      19
# human molecular genetics                                   19
# plos neglected tropical diseases                           20
# proceedings of the national academy of sciences            22
# plos pathogens                                             24
# plos genetics                                              24
# nucleic acids research                                     26
# neuroimage                                                 29
# journal of biological chemistry                            53
# plos one                                                  190
# Name: journal_title, Length: 894, dtype: int64

# %%
pd.set_option('display.max_colwidth', -1)
journal[journal.str.startswith('a', na=False)]
# Out:
# 439     academy of nutrition and dietetics
# 8       acs chemical biology
# 9       acs chemical biology
# 21      acs chemical biology
# 20      acs chemical biology
# 19      acs chemical biology
# 22      acs chemical neuroscience
# 34      acs nano
# 23      acs nano
# 927     acta crystallographica section d,  biological crystallography
# 920     acta crystallographica section d: biological crystallography
# 928     acta crystallographica section f: structural biology and crystallization communications
# 929     acta crystallographica section f: structural biology and crystallization communications
# 921     acta crystallographica, section d
# 922     acta crystallography d
# 923     acta d
# 1711    acta dermato venereologica
# 1716    acta diabetologica
# 924     acta f
# 1717    acta neuropathol
# 1718    acta neuropathologica
# 1719    acta neuropathologica
# 1720    acta neuropathologica
# 2051    acta opthalmologica
# 1871    acta physiol
# 1873    addiction
# 1872    addiction
# 1722    advances in experimental medicine and biology
# 1723    advances in experimental medicine and biology
# 1721    advances in experimental medicine and biology
#                             ...
# 1814    annals of science
# 1887    annals of the new york academy of sciences
# 1886    annals of the new york academy of sciences
# 342     antimicobial agents and chemotherapy
# 82      antimicrobial agents and chemotherapy
# 83      antimicrobial agents and chemotherapy
# 84      antimicrobial agents and chemotherapy
# 167     antimicrobial agents and chemotherapy
# 85      antimicrobial agfents and chemotherapy
# 987     antioxidants & redox signaling
# 990     antioxidants and redox signaling
# 988     antioxidants and redox signaling
# 450     applied energy
# 303     archives of disease in childhood
# 304     archives of disease in childhood
# 319     archives of disease in childhood
# 1889    arthritis & rheumatism
# 1888    arthritis & rheumatism
# 1890    arthritis & rheumatism
# 1892    arthritis and rheumatism
# 1891    arthritis and rheumatism
# 175     arthritis research & therapy
# 252     arthritis research and therapy
# 451     asian journal of psychiatry
# 452     asian journal of psychiatry
# 1317    asn neuro
# 453     atherosclerosis
# 454     atherosclerosis
# 969     autophagy
# 1810    azania: archaeological research in africa
# Name: journal_title, Length: 134, dtype: object

# %%
journal.loc[927] = 'acta crystallographica section d: biological crystallography'
journal.loc[920] = 'acta crystallographica section d: biological crystallography'
journal.loc[921] = 'acta crystallographica section d: biological crystallography'
journal.loc[922] = 'acta crystallographica section d: biological crystallography'
journal.loc[923] = 'acta crystallographica section d: biological crystallography'

journal.loc[1717] = 'acta neuropathologica'

journal.loc[924] = 'acta crystallographica section f: structural biology and crystallization communications'
journal.loc[85] = 'antimicrobial agents and chemotherapy'
journal.loc[987] = 'antioxidants and redox signaling'

journal.loc[1889] = 'arthritis and rheumatism'
journal.loc[1888] = 'arthritis and rheumatism'
journal.loc[1890] = 'arthritis and rheumatism'

journal.loc[175] = 'arthritis research and therapy'

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('b', na=False)]
# Out:
# 455     bba - molecular basis of disease
# 456     behavior research and therapy
# 457     behavior research and therapy
# 47      behavioral neuroscience
# 46      behavioral neuroscience
# 45      behavioral neuroscience
# 459     behaviour research and therapy
# 458     behaviour research and therapy
# 460     behavioural brain research
# 1188    biinformatics
# 173     biochem journal
# 1328    biochem soc trans
# 461     biochemical and biophysical research communications
# 462     biochemical and biophysical research communications
# 1319    biochemical journal
# 1320    biochemical journal
# 1321    biochemical journal
# 1331    biochemical journal
# 1332    biochemical journal
# 1333    biochemical journal
# 1334    biochemical journal
# 1335    biochemical journal
# 1336    biochemical journal
# 1329    biochemical journal
# 1330    biochemical journal
# 1318    biochemical journal
# 1322    biochemical journals
# 463     biochemical pharmacology
# 1337    biochemical society transactions
# 1323    biochemical society transactions
#                       ...
# 1728    brain structure and function
# 1729    brain topography
# 1122    briefings in bioinformatics
# 1204    briefings in functional genomics
# 1203    briefings in functional genomics
# 2058    british jounal of pharmacology
# 354     british journal for the history of science
# 1028    british journal of cancer
# 1027    british journal of cancer
# 1899    british journal of clinical pharmacology
# 2059    british journal of clinical pharmacology
# 1900    british journal of dermatology
# 2024    british journal of dermatology
# 1901    british journal of haematology
# 286     british journal of ophthalmology
# 287     british journal of opthalmology
# 2061    british journal of pharmacology
# 1902    british journal of pharmacology
# 2060    british journal of pharmacology
# 1904    british journal of pharmacology
# 1903    british journal of pharmacology
# 1857    british journal of psychiatry
# 1624    british journal of psychiatry
# 355     british journal of the history of science
# 1123    british medical bulletin
# 288     british medical journal
# 1205    british medical journal
# 1625    britsh journal of psychiatry
# 2009    brt jnl clinical pharmacology
# 959     bulletin of the history of medicine
# Name: journal_title, Length: 218, dtype: object

# %%
journal.loc[459] = 'behavior research and therapy'
journal.loc[458] = 'behavior research and therapy'
journal.loc[460] = 'behavior brain research'

journal.loc[173] = 'biochemical journal'
journal.loc[1322] = 'biochemical journal'
journal.loc[1328] = 'biochemical society transactions'
# 468 biochimie
journal.loc[1856] = 'bjophthalmol'

journal.loc[181] = 'bmc genomics'
journal.loc[2009] = 'british journal of pharmacology'

journal.loc[287] = 'british journal of ophthalmology '

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('c', na=False)]
# Out:
# 1730    calcified tissue international
# 1815    canadian journal of african studies
# 486     cancer letters
# 1865    cancer research
# 1268    cardiovascular research
# 1272    cardiovascular research
# 1166    cardiovascular research
# 487     cell
# 491     cell
# 490     cell
# 489     cell
# 488     cell
# 970     cell adhesion and migration
# 1731    cell and tissue research
# 492     cell calcium
# 974     cell cycle
# 983     cell cycle
# 971     cell cycle
# 973     cell cycle
# 984     cell cycle
# 972     cell cycle
# 1031    cell death & disease
# 1029    cell death & disease
# 1030    cell death & disease
# 1032    cell death and differentiation
# 1050    cell death and disease
# 1033    cell death and disease
# 1056    cell death differentiation
# 844     cell host & microbe
# 493     cell host and microbe
#                 ...
# 509     consciousness and cognition
# 512     cortex
# 1621    cortex
# 514     cortex
# 515     cortex
# 513     cortex
# 511     cortex
# 266     cost effectiveness and resource allocation
# 2064    criminal behavior and mental health
# 841     curr biol.
# 170     current analytical chemistry
# 1741    current atherosclerosis reports
# 1742    current atherosclerosis reports
# 516     current biology
# 518     current biology
# 526     current biology
# 519     current biology
# 520     current biology
# 521     current biology
# 522     current biology
# 523     current biology
# 524     current biology
# 525     current biology
# 517     current biology
# 1743    current obstetrics and gynecology reports
# 527     current opinion in neurobiology
# 528     current opinion microbiology
# 529     current opinions in neurobiology
# 169     current topics in medicinal chemistry
# 1912    cytoskeleton
# Name: journal_title, Length: 146, dtype: object

# %%
journal.loc[1031] = 'cell death and disease'
journal.loc[1029] = 'cell death and disease'
journal.loc[1030] = 'cell death and disease'

journal.loc[844] = 'cell host and microbe'
journal.loc[1056] = 'cell death and differentiation'
journal.loc[2010] = 'child: care, heath & development'

journal.loc[1130] = 'clinical infectious diseases'

journal.loc[508] = 'consciousness and cognition'
journal.loc[841] = 'current biology'
journal.loc[527] = 'current opinions in neurobiology'

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('d', na=False)]
# Out:
# 1652    dalton transactions
# 1213    database
# 2065    depression and anxiety
# 2066    dermatologic surgery
# 2034    dev world bioeth.
# 2035    dev world bioeth.
# 2036    dev world bioeth.
# 2037    dev. world bioeth
# 2038    dev. world bioeth
# 1869    developing world bioethics
# 1913    developing world bioethics
# 2011    developing world bioethics
# 396     development
# 395     development
# 394     development
# 393     development
# 392     development
# 391     development
# 390     development
# 1842    development
# 1844    development
# 530     development cell
# 1914    development dynamics
# 1744    development genes and evolution
# 949     development science
# 531     developmental biology
# 538     developmental cell
# 535     developmental cell
# 534     developmental cell
# 533     developmental cell
# 532     developmental cell
# 537     developmental cell
# 536     developmental cell
# 542     developmental cell
# 397     developmental cell
# 539     developmental cell
# 541     developmental cell
# 540     developmental cell
# 543     developmental cognitive neuroscience
# 544     developmental cognitive neuroscience
# 1915    developmental science
# 1916    diabetic medicine
# 2067    diabetic medicine
# 1917    diabetic medicine
# 1918    diabetic medicine
# 1747    diabetologia
# 1745    diabetologia
# 1746    diabetologia
# 545     diagnostic microbiology and infectious disease
# 398     disease models and mechanisms
# 1839    disease models and mechanisms
# 2012    drug and alcohol review
# Name: journal_title, dtype: object

# %%
journal.loc[2034] = 'developing world bioethics'
journal.loc[2035] = 'developing world bioethics'
journal.loc[2036] = 'developing world bioethics'
journal.loc[2037] = 'developing world bioethics'
journal.loc[2038] = 'developing world bioethics'

journal.loc[530] = 'developmental cell'

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('j', na=False)]
# Out:
# 119     j biol chem.
# 62      j biol chem.
# 118     j biol chem.
# 117     j biol chem.
# 63      j biol chem.
# 120     j biol chemistry
# 1623    j cardiovasc magn reson
# 399     j cell sci.
# 344     j clin microbiol
# 433     j immunol
# 427     j immunol
# 1266    j infect dis
# 2       j med chem
# 3       j med chem
# 1832    j med chem.
# 1831    j med chem.
# 1829    j med chem.
# 1830    j med chem.
# 933     j med internet research
# 599     j mol biol
# 4       j org chem
# 600     j steroid biochem mol biol
# 925     j synchrotron radiat.
# 2119    jaids journal of acquired immune deficiency syndromes
# 993     jerph
# 338     jnl biological chemistry
# 161     jnl biological chemistry
# 1835    jnl biological chemistry
# 360     jnl of the international neuropsychological society
# 111     jounral of clinical microbiology
#                       ...
# 1858    journal of the royal society interface
# 1637    journal of the royal society interface
# 1634    journal of the royal society interface
# 1635    journal of the royal society interface
# 1636    journal of the royal society interface
# 1673    journal of the royal society of medicine short reports
# 1672    journal of the royal society of medicine short reports
# 1638    journal of the royal society, interface
# 1970    journal of the royal statistical society: series c (applied statistics)
# 644     journal of transport geography
# 2092    journal of viral hepatitis
# 377     journal of virol
# 645     journal of virological methods
# 93      journal of virology
# 166     journal of virology
# 95      journal of virology
# 94      journal of virology
# 113     journal of virology
# 99      journal of virology
# 112     journal of virology
# 647     journal of virology
# 646     journal of virology
# 168     journal of vision
# 997     journal of visualized experiements
# 1000    journal of visualized experiments
# 1001    journal of visualized experiments
# 962     journal of visualized experiments
# 961     journal of visualized experiments
# 998     journal of visualized experiments
# 999     journal of visulaized expermiments
# Name: journal_title, Length: 351, dtype: object

# %%
journal.loc[119] = 'journal of biological chemistry'
journal.loc[62] = 'journal of biological chemistry'
journal.loc[118] = 'journal of biological chemistry'
journal.loc[117] = 'journal of biological chemistry'
journal.loc[63] = 'journal of biological chemistry'
journal.loc[120] = 'journal of biological chemistry'
journal.loc[338] = 'journal of biological chemistry'
journal.loc[161] = 'journal of biological chemistry'
journal.loc[1835] = 'journal of biological chemistry'
journal.loc[164] = 'journal of biological chemistry'
journal.loc[162] = 'journal of biological chemistry'

journal.loc[2] = 'journal of medicinal chemistry'
journal.loc[3] = 'journal of medicinal chemistry'
journal.loc[1832] = 'journal of medicinal chemistry'
journal.loc[1831] = 'journal of medicinal chemistry'
journal.loc[1829] = 'journal of medicinal chemistry'
journal.loc[1830] = 'journal of medicinal chemistry'

journal.loc[1638] = 'journal of the royal society interface'

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('n', na=False)]
# Out:
# 676     n biotechnol.
# 914     nanotechnology
# 915     nanotechnology
# 1307    national academy of sciences
# 960     national academy of sciences
# 1339    national academy of sciences
# 1047    nature communications
# 1046    nature communications
# 1045    nature communications
# 1044    nature communications
# 1043    nature communications
# 1085    nature communications
# 1076    nature communications
# 1077    nature communications
# 1078    nature communications
# 1080    nature communications
# 1081    nature communications
# 1082    nature communications
# 1083    nature communications
# 1084    nature communications
# 1105    nature communications
# 1054    nature communications
# 1042    nature communications
# 1079    nature communications
# 1041    nature communications
# 1055    nature neuroscience
# 1086    nature scientific reports
# 1343    neglected tropical disease
# 1344    neglected tropical disease
# 1236    nephrology dialysis and transplantation
#                          ...
# 1238    nucleic acid research
# 1239    nucleic acid research
# 1240    nucleic acid research
# 1248    nucleic acids research
# 1249    nucleic acids research
# 1250    nucleic acids research
# 1251    nucleic acids research
# 1252    nucleic acids research
# 1253    nucleic acids research
# 1254    nucleic acids research
# 1155    nucleic acids research
# 1154    nucleic acids research
# 1148    nucleic acids research
# 1151    nucleic acids research
# 1274    nucleic acids research
# 1158    nucleic acids research
# 1157    nucleic acids research
# 1156    nucleic acids research
# 1150    nucleic acids research
# 1149    nucleic acids research
# 1152    nucleic acids research
# 1153    nucleic acids research
# 1241    nucleic acids research
# 1246    nucleic acids research
# 1245    nucleic acids research
# 1244    nucleic acids research
# 1243    nucleic acids research
# 1242    nucleic acids research
# 1247    nucleic acids research
# 219     nutrition journal
# Name: journal_title, Length: 155, dtype: object

# %%
journal.loc[1238] = 'nucleic acids research'
journal.loc[1239] = 'nucleic acids research'
journal.loc[1240] = 'nucleic acids research'

# %%
apc_spend['journal_title'] = journal

# %%
journal[journal.str.startswith('p', na=False)]
# Out:
# 755     pain
# 754     pain
# 753     pain
# 752     pain
# 233     parasit vectors.
# 1993    parasite immunology
# 1994    parasite immunology
# 273     parasites and vectors
# 221     parasites and vectors
# 364     parasitology
# 349     parasitology
# 365     parasitology
# 366     parasitology
# 367     parasitology
# 363     parasitology
# 756     parkinsonism and related disorders
# 757     parsitology
# 2124    pediatr infect dis j
# 1836    pediatrics
# 758     personality and individual differences
# 1779    pflugers archiv
# 1780    pflugers archive
# 1639    philos trans r soc london b biol sci
# 1640    philosophical transactions b
# 1641    philosophical transactions b
# 1859    philosophical transactions of the royal society of london. series b, biological sciences
# 1653    photochemical & photobiological sciences
# 930     physics in biology and medicine
# 1995    plant biotechnology journal
# 1345    plos
#         ...
# 1645    proceedings of the royal society b: biological sciences
# 1257    protein engineering, design and selection (
# 765     protein expr purif.
# 1997    protein science
# 1996    protein science
# 2113    protemics
# 766     protist
# 55      psychological assessment
# 0       psychological medicine
# 411     psychological medicine
# 413     psychological medicine
# 412     psychological medicine
# 368     psychological medicine
# 56      psychological review
# 1667    psychological science
# 1671    psychological science
# 57      psychological trauma: theory research, practice and policy
# 1782    psychopharmacology
# 1783    psychopharmacology
# 1781    psychopharmacology
# 222     public health
# 767     public health
# 1159    public health ethics
# 369     public health nutrition
# 414     public health nutrition
# 1617    public library of science
# 1618    public library of science one
# 1619    public service review
# 768     pulmonary pharmacology & therapeutics
# 370     pyschological medicine
# Name: journal_title, Length: 417, dtype: object

# %%
journal.loc[1350] = 'plos one'
journal.loc[1351] = 'plos one'
journal.loc[1353] = 'plos one'
journal.loc[1354] = 'plos one'
journal.loc[1355] = 'plos one'
journal.loc[1356] = 'plos one'
journal.loc[1357] = 'plos one'
journal.loc[1352] = 'plos one'

journal.loc[1393] = 'plos neglected tropical diseases'
journal.loc[1281] = 'plos neglected tropical diseases'

journal.loc[1612] = 'plos one'
journal.loc[1613] = 'plos one'
journal.loc[1611] = 'plos one'
journal.loc[1608] = 'plos one'
journal.loc[1609] = 'plos one'
journal.loc[1607] = 'plos one'
journal.loc[1606] = 'plos one'
journal.loc[1605] = 'plos one'
journal.loc[1610] = 'plos one'

journal.loc[1314] = 'proceedings of the national academy of sciences of the united states of america'
journal.loc[1004] = 'proceedings of the national academy of sciences of the united states of america'
journal.loc[1313] = 'proceedings of the national academy of sciences of the united states of america'

# %%
apc_spend['journal_title'] = journal

# %%
apc_spend.head()
# Out:
#   publisher                   journal_title  \
# 0  CUP       psychological medicine
# 1  ACS       biomacromolecules
# 2  ACS       journal of medicinal chemistry
# 3  ACS       journal of medicinal chemistry
# 4  ACS       j org chem
#
#                                                                                                                              article_title  \
# 0  Reduced parahippocampal cortical thickness in subjects at ultra-high risk for psychosis
# 1  Structural characterization of a Model Gram-negative bacterial surface using lipopolysaccharides from rough strains of escherichia coli
# 2  Fumaroylamino-4,5-epoxymorphinans and related opioids with irreversible ? opioid receptor antagonist effects.
# 3  Orvinols with mixed kappa/mu opioid receptor agonist activity.
# 4  Regioselective opening of myo-inositol orthoesters: mechanism and synthetic utility.
#
#      cost
# 0  0.0
# 1  2381.0
# 2  643.0
# 3  670.0
# 4  686.0

# %% [markdown]
# ## Task #1: TOP 5 Journals

# %%
# Top Five Journals
journal.value_counts()[:5]
# Out:
# plos one                           207
# journal of biological chemistry    64
# nucleic acids research             29
# neuroimage                         29
# plos pathogens                     24
# Name: journal_title, dtype: int64

# %%
top_journals = apc_spend[(apc_spend['journal_title'] == 'plos one')
                |(apc_spend['journal_title'] == 'journal of biological chemistry')
                |(apc_spend['journal_title'] == 'nucleic acids research')
                |(apc_spend['journal_title'] == 'neuroimage')
                |(apc_spend['journal_title'] == 'plos genetics')]
                
top_journals.sort_values(by=['cost','journal_title'])
# Out:
#                                                              publisher  \
# 1469  Public Library of Science
# 1471  Public Library of Science
# 16    AMBSB
# 1472  Public Library of Science
# 161   ASBMB Cadmus
# 1304  PLoS (Public Library of Science)
# 1473  Public Library of Science
# 1305  PLoS (Public Library of Science)
# 1474  Public Library of Science
# 1240  Oxford University Press
# 1254  Oxford University Press
# 1475  Public Library of Science
# 1476  Public Library of Science
# 1477  Public Library of Science
# 1293  PLOS
# 1294  PLoS
# 1295  PLOS
# 1478  Public Library of Science
# 1479  Public Library of Science
# 1480  Public Library of Science
# 1481  Public Library of Science
# 1482  Public Library of Science
# 1483  Public Library of Science
# 1484  Public Library of Science
# 1485  Public Library of Science
# 1486  Public Library of Science
# 1487  Public Library of Science
# 1488  Public Library of Science
# 1489  Public Library of Science
# 1490  Public Library of Science
# ...                         ...
# 702   Elsevier
# 703   Elsevier
# 148   ASBMB
# 438   Elseveier Science
# 704   Elsevier
# 705   Elsevier
# 706   Elsevier
# 707   Elsevier
# 708   Elsevier
# 709   Elsevier
# 710   Elsevier
# 711   Elsevier
# 712   Elsevier
# 713   Elsevier
# 77    American Society for Biochemistry and Molecular Biology
# 714   Elsevier
# 715   Elsevier
# 1470  Public Library of Science
# 149   ASBMB
# 1835  The American Society for Biochemistry and Molecular Biology, Inc
# 1386  Public Library of Science
# 1387  Public Library of Science
# 1560  Public Library of Science
# 1561  Public Library of Science
# 1562  Public Library of Science
# 1563  Public Library of Science
# 1564  Public Library of Science
# 1565  Public Library of Science
# 1566  Public Library of Science
# 1612  Public Library of Science
#
#                         journal_title  \
# 1469  plos one
# 1471  plos one
# 16    journal of biological chemistry
# 1472  plos one
# 161   journal of biological chemistry
# 1304  plos one
# 1473  plos one
# 1305  plos one
# 1474  plos one
# 1240  nucleic acids research
# 1254  nucleic acids research
# 1475  plos one
# 1476  plos one
# 1477  plos one
# 1293  plos one
# 1294  plos one
# 1295  plos one
# 1478  plos one
# 1479  plos one
# 1480  plos one
# 1481  plos one
# 1482  plos one
# 1483  plos one
# 1484  plos one
# 1485  plos one
# 1486  plos one
# 1487  plos one
# 1488  plos one
# 1489  plos one
# 1490  plos one
# ...        ...
# 702   neuroimage
# 703   neuroimage
# 148   journal of biological chemistry
# 438   neuroimage
# 704   neuroimage
# 705   neuroimage
# 706   neuroimage
# 707   neuroimage
# 708   neuroimage
# 709   neuroimage
# 710   neuroimage
# 711   neuroimage
# 712   neuroimage
# 713   neuroimage
# 77    journal of biological chemistry
# 714   neuroimage
# 715   neuroimage
# 1470  plos one
# 149   journal of biological chemistry
# 1835  journal of biological chemistry
# 1386  plos genetics
# 1387  plos genetics
# 1560  plos one
# 1561  plos one
# 1562  plos one
# 1563  plos one
# 1564  plos one
# 1565  plos one
# 1566  plos one
# 1612  plos one
#
#                                                                                                                                                                               article_title  \
# 1469  How  well are Malaria Maps used to design and finance Malaria control in Africa
# 1471  Neighbourhood, route and workplace-related environmental characteristics predict adults' mode of travel to work
# 16    Annexin-1 interaction with FPR2/ALX
# 1472  Socioeconomic inequalities in non-communicable diseases prevalence in India: disparities between . . .
# 161   Biochemical and immunological characterisation of Toxoplasma gondii macrophage migration inhibitory factor
# 1304  Prolonged internal displacement and common mental disorders in Sri Lanka_ the COMRAID study
# 1473  Superantigenic activity of emm3 streptococcus pyogenes is abrogated by conserved naturally occuring smeZ mutation
# 1305  Genetics of callous-unemotional behavior in children
# 1474  Towards Clinical Molecular Diagnosis of Inherited Cardiac Conditions: A Comparison of Bench-Top Genome DNA Sequencers
# 1240  Space exploration by the promoter of a long human gene during one transcription cycle
# 1254  AT-rich sequence elements promote nascent transcript cleavage leading to RNA polymerase ii termination
# 1475  Determinants of change in children's sedentary time
# 1476  Health Impact Modelling of Active Travel Visions for England and Wales using an Integrated Transport and Health Impact Modelling tool (ITHIM)
# 1477  Mast cells express 11?-hydroxysteroid dehydrogenase type 1: a role in restraining mast cell degranulation.
# 1293  A Method for Positive and Negative Selection of Plasmodium falciparum Platelet-Mediated Clumping Parasites
# 1294  On the importance of countergradients for the development of retinotopy: Insights from a generalised \nInsights from a generalised
# 1295  Telomeric repeats facilitate CENP-ACnp1 incorporation via telomere binding proteins
# 1478  A cost effectiveness and capacity analysis for the introduction of universal rotavirus vaccination in Kenya: comparison between Rotarix and RotaTeq vaccines.
# 1479  Costs and cost-effectiveness of a mobile phone text-message reminder programmes to improve health workers' adherence to malaria guidelines in Kenya
# 1480  The Incidence and Clinical Burden of Respiratory Syncytial Virus Disease Identified through Hospital Outpatient Presentations in Kenyan Children.
# 1481  Lack of Avidity Maturation of Merozoite Antigen-Specific Antibodies with Increasing Exposure to Plasmodium falciparum amongst Children and Adults Exposed to Endemic Malaria in Kenya
# 1482  A Statistical Interaction between Circumsporozoite Protein-Specific T Cell and Antibody Responses and Risk of Clinical Malaria Episodes following Vaccination with RTS,S/AS01E.
# 1483  Understanding the Impact of subsidizing Artemisinin-based  Combination Therapies (ACTs) in the Retail Sector - Results from Focus Group Discussion in rural Kenya
# 1484  Comparison of alternative evidence summary and presentation formats in clinical guideline development: a mixed-method study.
# 1485  "The words will pass with the blowing wind"; staff and parent views of the deferred consent process, with prior assent, used in an emergency fluids trial in two African hospitals
# 1486  The ratio of monocytes to lymphocytes in peripheral blood correlates with increased susceptibility to clinical malaria in Kenyan children.
# 1487  Childhood Malaria Admission Rates to Four Hospitals in Malawi between 2000 and 2010.
# 1488  Malaria Control and the intensity of Plasmodium Falciparum Transmission in Namibia 1969-1992
# 1489  Assessment of health benefits and cost-effectiveness of 10-valent and 13-valent pneumococcal conjugate vaccination in Kenyan children.
# 1490  Exclusive breastfeeding, diarrhoel morbidity and all-couse mortality in infnats of HIV infected
# ...                                                                                               ...
# 702   Dynamic Causal Modelling of lateral interactions in the visual cortex
# 703   Complex spatiotemporal haemodynamic response following sensory stimulation in the awake rat
# 148   Cell Cycle-dependent Regulation of the Forkhead Transcription Factor FOXK2 by CDK·Cyclin Complexes
# 438   Good practice for conducting and reporting MEG research
# 704   Articulatory movements modulate auditory responses to speech
# 705   A quantitative meta-analysis and review of motor learning in the human brain
# 706   Network discovery with large DCMs
# 707   Network reconfiguration and working memory impairment in mesial temporal lobe epilepsy
# 708   Investigating the need of triggering the acquisition for infant diffusion MRI: A quantitative study including bootstrap statistics
# 709   Early visual learning induces long-lasting connectivity changes during rest in the human brain
# 710   Movement related dynamics of subthalmo-cortical alpha connectivity in Parkinson's Disease
# 711   A multivariate method to determine the dimensionality of neural representation from population activity
# 712   The impact of post-processing on spinal cord diffusion tensor imaging
# 713   Functional Specialization and Generalization for Grouping of Stimuli Based on Colour and Motion
# 77    ca2+ signalling through catsper and ca2+ stores regulate different behaviours in human sperm
# 714   Auditory Modulation of Visual Stimulus Encoding in Human Retinotopic Cortex
# 715   Set-level threshold-free tests on the intrinsic volumes of SPMs
# 1470  Reducing stock-outs of life saving Malaria Commodities using mobile phone text-messaging: SMS for life study in Kenya
# 149   Picomolar nitric oxide signals from central neurons recorded using ultrasensitive detector cells
# 1835  Photoaffinity labelling of high affinity nicotinic acid adenine dinucleotide 2'-phosphate (NAADP) proteins in sea urchin egg
# 1386  Population genomics of the Wolbachia endosymbiont in Drosophila\nmelanogaster
# 1387  PNUTS/PP1 regulates RNAPII-mediated gene expression and is necessary for developmental growth
# 1560  Plasmodium falciparum vary Gene Expression Homogeneity as a Marker of the Host-Parasite Relationship under Different Levels of Naturally Acquired Immunity to Malaria.
# 1561  Pharmacological inhibition of caspase-2 protects axotomised retinal ganglion cells from apoptosis i
# 1562  Population-based CD4 counts in a rural area in South Africa with high HIV prevalence and high antire
# 1563  Plant SILAC: stable-isotope labelling with amino acids of arabidopsis seedlings for quantitative proteomics.
# 1564  Phagocytosis Is the Main CR3-Mediated Function Affected by the Lupus-Associated Variant of CD11b in Human Myeloid Cells.
# 1565  Pneumocystis jirovecii pneumonia in tropical and low and middle income countries: a systematic review and meta-regression
# 1566  Phenotypic alteration of neutrophils in the blood of HIV seropositive patients
# 1612  Retinal Nerve Fibre Layer Thickness and Contrast Sensitivity in HIV-Infected Individuals in South Africa: A Case-Control Study.
#
#           cost
# 1469  122.0
# 1471  215.0
# 16    266.0
# 1472  330.0
# 161   381.0
# 1304  390.0
# 1473  425.0
# 1305  443.0
# 1474  534.0
# 1240  710.0
# 1254  710.0
# 1475  741.0
# 1476  747.0
# 1477  773.0
# 1293  795.0
# 1294  809.0
# 1295  819.0
# 1478  826.0
# 1479  826.0
# 1480  826.0
# 1481  826.0
# 1482  826.0
# 1483  826.0
# 1484  826.0
# 1485  826.0
# 1486  826.0
# 1487  826.0
# 1488  826.0
# 1489  826.0
# 1490  826.0
# ...     ...
# 702   2326.0
# 703   2344.0
# 148   2345.0
# 438   2345.0
# 704   2383.0
# 705   2385.0
# 706   2395.0
# 707   2396.0
# 708   2397.0
# 709   2421.0
# 710   2432.0
# 711   2446.0
# 712   2466.0
# 713   2484.0
# 77    2501.0
# 714   2503.0
# 715   2503.0
# 1470  192645.0
# 149   999999.0
# 1835  999999.0
# 1386  999999.0
# 1387  999999.0
# 1560  999999.0
# 1561  999999.0
# 1562  999999.0
# 1563  999999.0
# 1564  999999.0
# 1565  999999.0
# 1566  999999.0
# 1612  999999.0
#
# [353 rows x 4 columns]

# %% [markdown]
# There are quite a few rows that have a ridiculous cost of 999,999.  And unfortunately we have no idea what the cost might be as all the article_titles are unique.  So I can either remove the rows or calculate the mean or median of articles for each journal and use that for the cost.  Though these are only 12 rows out of a total of 353, which accounts for 0.03 percent of the journals.  Interestingly 10 of those are from the Public Library of Science publisher.

# %%
# Remove rows where cost is > 150000
too_much = apc_spend[apc_spend.cost > 150000].index
apc_spend.drop(too_much, inplace=True)

# Better to remove extreme outliers than changing with mean or median per mentor

# %%
apc_spend.sort_values(by=['cost','journal_title'])
# Out:
#                              publisher  \
# 0     CUP
# 243   BioMed Central Ltd
# 100   American Society for Nutrition
# 1469  Public Library of Science
# 1677  Sciedu Press
# 975   Landes Bioscience
# 963   JSciMed Central
# 1676  Sciedu Press
# 1311  PNAS
# 1471  Public Library of Science
# 15    AGA Institute
# 16    AMBSB
# 1325  Portland Press
# 970   Landes Bioscience
# 31    American Chemical Society
# 1391  Public Library of Science
# 1472  Public Library of Science
# 930   IOP Publishing
# 1359  Public Library of Science
# 879   Frontiers
# 524   Elsevier
# 539   Elsevier
# 866   Ferrata Storti Foundation
# 1266  Oxford University Press
# 161   ASBMB Cadmus
# 222   BioMed Central
# 1304  PLoS (Public Library of Science)
# 1005  National Academy of Sciences
# 980   Landes Bioscience
# 978   Landes Bioscience
# ...                 ...
# 422   Dartmouth Journal Services
# 538   Elsevier
# 523   Elsevier
# 423   Dartmouth Journal Services
# 726   Elsevier
# 540   Elsevier
# 727   Elsevier
# 494   Elsevier
# 587   Elsevier
# 785   Elsevier
# 541   Elsevier
# 525   Elsevier
# 831   Elsevier
# 786   Elsevier
# 542   Elsevier
# 728   Elsevier
# 526   Elsevier
# 668   Elsevier
# 841   Elsevier B.V.
# 490   Elsevier
# 729   Elsevier
# 844   Elsevier/Cell Press
# 796   Elsevier
# 799   Elsevier
# 797   Elsevier
# 552   Elsevier
# 648   Elsevier
# 798   Elsevier
# 800   Elsevier
# 1619  public.service.co.uk
#
#                                           journal_title  \
# 0     psychological medicine
# 243   veterinary research
# 100   american society for nutrition
# 1469  plos one
# 1677  journal of biomedical graphics and computing
# 975   channels
# 963   journal of neurology & translational neuroscience
# 1676  international journal of financial research
# 1311  proceedings of the national academy of sciences
# 1471  plos one
# 15    gastroenterology
# 16    journal of biological chemistry
# 1325  essays in biochemistry
# 970   cell adhesion and migration
# 31    journal of medicinal chemistry
# 1391  plos medicine
# 1472  plos one
# 930   physics in biology and medicine
# 1359  plos biology
# 879   frontiers in genetics
# 524   current biology
# 539   developmental cell
# 866   haematologica/the haematology journal
# 1266  j infect dis
# 161   journal of biological chemistry
# 222   public health
# 1304  plos one
# 1005  proceedings of the national academy of sciences
# 980   rna biology
# 978   epigentics
# ...          ...
# 422   cell reports
# 538   developmental cell
# 523   current biology
# 423   cell reports
# 726   neuron
# 540   developmental cell
# 727   neuron
# 494   cell journal
# 587   immunity
# 785   structure
# 541   developmental cell
# 525   current biology
# 831   cell metabolism
# 786   structure
# 542   developmental cell
# 728   neuron
# 526   current biology
# 668   molecular cell
# 841   current biology
# 490   cell
# 729   neuron
# 844   cell host and microbe
# 796   the lancet
# 799   the lancet neurology
# 797   the lancet
# 552   elsevier
# 648   lancet
# 798   the lancet
# 800   the lancet neurology
# 1619  public service review
#
#                                                                                                                                                                                                              article_title  \
# 0     Reduced parahippocampal cortical thickness in subjects at ultra-high risk for psychosis
# 243   Understanding foot-and-mouth disease virus transmission biology: identification of the indicators of infectiousness
# 100   The association between breastfeeding and HIV on postpartum maternal weight changes over 24 months in rural South Africa
# 1469  How  well are Malaria Maps used to design and finance Malaria control in Africa
# 1677  Functional MRI demonstrates pain perception in hand osteoarthritis has features of central pain processing
# 975   State-independent intracellular access of quatemary ammonium blockers to the pore of TREK-1
# 963   Parkinson's Disease: The Catabolic Theory
# 1676  Determinants of Enrolment in Voluntary Health Insurance: Evidences from a Mixed Method Study, Kerala, India
# 1311  Multistep molecular mechanism for Bone morphogenetic protein extracellular transport in the Drosophila embryo
# 1471  Neighbourhood, route and workplace-related environmental characteristics predict adults' mode of travel to work
# 15    Much of the genetic risk of colorectal cancer is likely to be mediated through susceptibility to adenomas
# 16    Annexin-1 interaction with FPR2/ALX
# 1325  Cells wars: regulation of cell survival and proliferation by cell competition
# 970   Emerging roles for semaphorins & VEGFs in synaptogenesis and synaptic platicity
# 31    A class of 5-nitro-2-furancarboxylamides with potent trypanocidal activity against Trypanosoma brucei in vitro
# 1391  Associations between active travel to work andn overweight, hyperension and diabetis in India: cross
# ..
# 1472  Socioeconomic inequalities in non-communicable diseases prevalence in India: disparities between . . .
# 930   Visualization of small lesions in rat cartilage by means of laboratory-based x-ray phase contrast imaging
# 1359  Radar tracking and motion-sensitive cameras on flowers reveal the development of pollinator multi-destination routes over large spacial scales
# 879   The mysterious case of the C. elegans gut granule: death fluorescence, anthranilic acid and the kynurenine pathway
# 524   Disrupted Circadian Rhythms in a Mouse Model of Schizophrenia
# 539   Chromosome engineering allows the efficient isolation of vertebrate neocentromeres.
# 866   Production of the effector cytokine interleukin-17, rather than interferon-y, is more strongly asociated with autoimmune hemolytic anaemia
# 1266  Genetic Relatedness of Infecting and Reinfecting Respiratory Syncytial Virus Strains Identified in a Birth Cohort From Rural Kenya
# 161   Biochemical and immunological characterisation of Toxoplasma gondii macrophage migration inhibitory factor
# 222   Walking and cycling to work despite reporting an unsupportive environment: insights from a mixed-method exploration of resilience
# 1304  Prolonged internal displacement and common mental disorders in Sri Lanka_ the COMRAID study
# 1005  Systematic identification of conserved bacterial c-di-AMP receptor proteins
# 980   Human pentatricopeptide proteins- only a few and what do they do?
# 978   On your histone mark, SET, methylate!
# ...                                     ...
# 422   Inhibition of mitochondrial aconitase by succination in fumarate hydratase deficiency.
# 538   Autoregulatory feedback controls sequential action of cis-regulatory modules at the brinker locus
# 523   M1 corticospinal mirror neurons and their role in movement suppression during action observation
# 423   c-Myc Induced Sebaceous Gland Differentiation is Controlled by an Androgen Receptor/p53 Axis
# 726   Nanoscale-targeted patch clamp recordings of functional presynaptic ion channels
# 540   Daughter cell identity emerges from the interplay of Cdc42, septins, and exocytosis
# 727   the emergence and representation of knowledge about social and non-social hierarchies
# 494   Exit from Pluripotency is Gated by Intracellular Redistribution of the bHLH transcription factor Tfe3
# 587   Dysregulated Hematopoietic Stem and Progenitor Cell Activity Promotes Interleukin-23-Driven Chronic Intestinal Inflammation
# 785   Structure of the Catalytic Region of DNA Ligase IV in Complex with an Artemis Fragment Sheds Light on Double-Strand Break Repair
# 541   Hec1-dependent cyclin B2 stabilisation regulates the G2-M transition and early prometaphase in mouse oocytes
# 525   Locomotion Controls Spatial Integration in Mouse Visual Cortex
# 831   Improved insulin sensitivity despite increased visceral adiposity in mice deficient for the immune cell transcription factor T-bet
# 786   The architecture of EssB, an integral membrane component of the type VII secretion system
# 542   Syndecan-4 phosphorylation is a control point for integrin recycling
# 728   Attention induced variance and noise correclation reduction on macaque V1 is mediated by NMDA receptors
# 526   A fovea for pain at the fingertips
# 668   Identification and Functional Characterization of FMN2, a Regulator of the Cyclin-Dependent Kinase Inhibitor p21
# 841   Calcium flashes orchestrate the wound inflammatory response through DUOX activation and hydrogen peroxide release.
# 490   Mapping the human miRNA interactome by CLASH reveals frequent non-canonical binding
# 729   Distinct contributions of rod, cone, and melanopsin photoreceptors to encoding irradiance
# 844   Human cytomegalovirus UL141 targets the TRAIL death receptors to inhibit host innate defenses
# 796   Dementia incidence and mortality in middle income countries, and associations with indicators of cognitive reserve: a 10/66 Dementia Research Group cohort study
# 799   MRI investigation of the sensorimotor cortex and the corticospinal tract after acute spinal cord injury: a prospective longitudinal study
# 797   The impact on a serogroup a meningococcal conjugate vaccine (PsA-TT) on serogroup A menigococcal meningitis and carriage in Chad.
# 552   Effects of relative weight gain and linear growth during early life on adult health and human capital in countries of low and middle income: findings from five birth cohort studies
# 648   Global trends in antiretroviral resistance in treatment-naive individuals with HIV after rollout of antiretroviral treatment in resource-limited settings: a global collaborative study and meta-regression analysis
# 798   Effects of unconditional and conditional cash transfers on child health and development in Zimbabwe: a cluster-randomised trial
# 800   Genetic risk factors for ischaemic stroke and its subtypes (the METASTROKE Collaboration): a meta-analysis of genome-wide association studies
# 1619  Laboratory Science in Tropical Medicine
#
#         cost
# 0     0.0
# 243   10.0
# 100   46.0
# 1469  122.0
# 1677  135.0
# 975   160.0
# 963   160.0
# 1676  187.0
# 1311  206.0
# 1471  215.0
# 15    238.0
# 16    266.0
# 1325  270.0
# 970   321.0
# 31    321.0
# 1391  328.0
# 1472  330.0
# 930   340.0
# 1359  344.0
# 879   346.0
# 524   348.0
# 539   364.0
# 866   379.0
# 1266  379.0
# 161   381.0
# 222   384.0
# 1304  390.0
# 1005  396.0
# 980   402.0
# 978   410.0
# ...     ...
# 422   3968.0
# 538   3976.0
# 523   3992.0
# 423   3996.0
# 726   3998.0
# 540   4002.0
# 727   4012.0
# 494   4041.0
# 587   4070.0
# 785   4072.0
# 541   4076.0
# 525   4078.0
# 831   4085.0
# 786   4096.0
# 542   4100.0
# 728   4105.0
# 526   4113.0
# 668   4148.0
# 841   4152.0
# 490   4164.0
# 729   4170.0
# 844   4226.0
# 796   4320.0
# 799   4320.0
# 797   4554.0
# 552   4800.0
# 648   4800.0
# 798   4800.0
# 800   5760.0
# 1619  6000.0
#
# [2077 rows x 4 columns]

# %%
apc_spend.dtypes
# Out:
# publisher        object
# journal_title    object
# article_title    object
# cost             float64
# dtype: object

# %%
apc_spend.groupby(by='journal_title')['cost'].sort()
apc_spend.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-023ae01d6043> in <module>
# ----> 1 apc_spend.groupby(by='journal_title')['cost'].sort()
#       2 apc_spend.head()
#
# TypeError: 'bool' object is not callable

# %%
# Rerunning this code again to see if values are changed
top_journals = apc_spend[(apc_spend['journal_title'] == 'plos one')
                |(apc_spend['journal_title'] == 'journal of biological chemistry')
                |(apc_spend['journal_title'] == 'nucleic acids research')
                |(apc_spend['journal_title'] == 'neuroimage')
                |(apc_spend['journal_title'] == 'plos genetics')]
                
top_journals.sort_values(by=['cost','journal_title'])
# Out:
#                                                     publisher  \
# 1469  Public Library of Science
# 1471  Public Library of Science
# 16    AMBSB
# 1472  Public Library of Science
# 161   ASBMB Cadmus
# 1304  PLoS (Public Library of Science)
# 1473  Public Library of Science
# 1305  PLoS (Public Library of Science)
# 1474  Public Library of Science
# 1240  Oxford University Press
# 1254  Oxford University Press
# 1475  Public Library of Science
# 1476  Public Library of Science
# 1477  Public Library of Science
# 1293  PLOS
# 1294  PLoS
# 1295  PLOS
# 1478  Public Library of Science
# 1479  Public Library of Science
# 1480  Public Library of Science
# 1481  Public Library of Science
# 1482  Public Library of Science
# 1483  Public Library of Science
# 1484  Public Library of Science
# 1485  Public Library of Science
# 1486  Public Library of Science
# 1487  Public Library of Science
# 1488  Public Library of Science
# 1489  Public Library of Science
# 1490  Public Library of Science
# ...                         ...
# 694   Elsevier
# 145   ASBMB
# 146   ASBMB
# 695   Elsevier
# 696   Elsevier
# 697   Elsevier
# 1149  OUP
# 698   Elsevier
# 61    American Society for Biochemistry and Molecular Biolgy
# 699   Elsevier
# 700   Elsevier
# 147   ASBMB
# 701   Elsevier
# 702   Elsevier
# 703   Elsevier
# 148   ASBMB
# 438   Elseveier Science
# 704   Elsevier
# 705   Elsevier
# 706   Elsevier
# 707   Elsevier
# 708   Elsevier
# 709   Elsevier
# 710   Elsevier
# 711   Elsevier
# 712   Elsevier
# 713   Elsevier
# 77    American Society for Biochemistry and Molecular Biology
# 714   Elsevier
# 715   Elsevier
#
#                         journal_title  \
# 1469  plos one
# 1471  plos one
# 16    journal of biological chemistry
# 1472  plos one
# 161   journal of biological chemistry
# 1304  plos one
# 1473  plos one
# 1305  plos one
# 1474  plos one
# 1240  nucleic acids research
# 1254  nucleic acids research
# 1475  plos one
# 1476  plos one
# 1477  plos one
# 1293  plos one
# 1294  plos one
# 1295  plos one
# 1478  plos one
# 1479  plos one
# 1480  plos one
# 1481  plos one
# 1482  plos one
# 1483  plos one
# 1484  plos one
# 1485  plos one
# 1486  plos one
# 1487  plos one
# 1488  plos one
# 1489  plos one
# 1490  plos one
# ...        ...
# 694   neuroimage
# 145   journal of biological chemistry
# 146   journal of biological chemistry
# 695   neuroimage
# 696   neuroimage
# 697   neuroimage
# 1149  nucleic acids research
# 698   neuroimage
# 61    journal of biological chemistry
# 699   neuroimage
# 700   neuroimage
# 147   journal of biological chemistry
# 701   neuroimage
# 702   neuroimage
# 703   neuroimage
# 148   journal of biological chemistry
# 438   neuroimage
# 704   neuroimage
# 705   neuroimage
# 706   neuroimage
# 707   neuroimage
# 708   neuroimage
# 709   neuroimage
# 710   neuroimage
# 711   neuroimage
# 712   neuroimage
# 713   neuroimage
# 77    journal of biological chemistry
# 714   neuroimage
# 715   neuroimage
#
#                                                                                                                                                                               article_title  \
# 1469  How  well are Malaria Maps used to design and finance Malaria control in Africa
# 1471  Neighbourhood, route and workplace-related environmental characteristics predict adults' mode of travel to work
# 16    Annexin-1 interaction with FPR2/ALX
# 1472  Socioeconomic inequalities in non-communicable diseases prevalence in India: disparities between . . .
# 161   Biochemical and immunological characterisation of Toxoplasma gondii macrophage migration inhibitory factor
# 1304  Prolonged internal displacement and common mental disorders in Sri Lanka_ the COMRAID study
# 1473  Superantigenic activity of emm3 streptococcus pyogenes is abrogated by conserved naturally occuring smeZ mutation
# 1305  Genetics of callous-unemotional behavior in children
# 1474  Towards Clinical Molecular Diagnosis of Inherited Cardiac Conditions: A Comparison of Bench-Top Genome DNA Sequencers
# 1240  Space exploration by the promoter of a long human gene during one transcription cycle
# 1254  AT-rich sequence elements promote nascent transcript cleavage leading to RNA polymerase ii termination
# 1475  Determinants of change in children's sedentary time
# 1476  Health Impact Modelling of Active Travel Visions for England and Wales using an Integrated Transport and Health Impact Modelling tool (ITHIM)
# 1477  Mast cells express 11?-hydroxysteroid dehydrogenase type 1: a role in restraining mast cell degranulation.
# 1293  A Method for Positive and Negative Selection of Plasmodium falciparum Platelet-Mediated Clumping Parasites
# 1294  On the importance of countergradients for the development of retinotopy: Insights from a generalised \nInsights from a generalised
# 1295  Telomeric repeats facilitate CENP-ACnp1 incorporation via telomere binding proteins
# 1478  A cost effectiveness and capacity analysis for the introduction of universal rotavirus vaccination in Kenya: comparison between Rotarix and RotaTeq vaccines.
# 1479  Costs and cost-effectiveness of a mobile phone text-message reminder programmes to improve health workers' adherence to malaria guidelines in Kenya
# 1480  The Incidence and Clinical Burden of Respiratory Syncytial Virus Disease Identified through Hospital Outpatient Presentations in Kenyan Children.
# 1481  Lack of Avidity Maturation of Merozoite Antigen-Specific Antibodies with Increasing Exposure to Plasmodium falciparum amongst Children and Adults Exposed to Endemic Malaria in Kenya
# 1482  A Statistical Interaction between Circumsporozoite Protein-Specific T Cell and Antibody Responses and Risk of Clinical Malaria Episodes following Vaccination with RTS,S/AS01E.
# 1483  Understanding the Impact of subsidizing Artemisinin-based  Combination Therapies (ACTs) in the Retail Sector - Results from Focus Group Discussion in rural Kenya
# 1484  Comparison of alternative evidence summary and presentation formats in clinical guideline development: a mixed-method study.
# 1485  "The words will pass with the blowing wind"; staff and parent views of the deferred consent process, with prior assent, used in an emergency fluids trial in two African hospitals
# 1486  The ratio of monocytes to lymphocytes in peripheral blood correlates with increased susceptibility to clinical malaria in Kenyan children.
# 1487  Childhood Malaria Admission Rates to Four Hospitals in Malawi between 2000 and 2010.
# 1488  Malaria Control and the intensity of Plasmodium Falciparum Transmission in Namibia 1969-1992
# 1489  Assessment of health benefits and cost-effectiveness of 10-valent and 13-valent pneumococcal conjugate vaccination in Kenyan children.
# 1490  Exclusive breastfeeding, diarrhoel morbidity and all-couse mortality in infnats of HIV infected
# ...                                                                                               ...
# 694   Neural correlates of working memory in Temporal Lobe Epilepsy - An fMRI study
# 145   Interactions between Kar2p and its nucleotide exchange factors Sil1p and Lhs1p are mechanistically distinct
# 146   Specific ?-containing integrins exert differential control on proliferation and 2D collective cell migration in mammary epithelial cells
# 695   Dynamic causal modelling of effective connectivity from fMRI: are results reproducible and sensitive to Parkinson's disease and its treatment?
# 696   Action selection: a race model for selected and non-selected actions distinguishes the contribution of premotor and prefrontal areas
# 697   Consistency and interpretation of changes in millimeter-scale cortical intrinsic curvature across three independent datasets in schizophrenia
# 1149  Impact of Target Site Distribution for Type I Restriction Enzymes on the Evolution of Methicillin Resistant Staphylococcus aureus (MRSA) Populations
# 698   Identification of gene pathways implicated in Alzheimer's disease using longitudinal imaging phenotypes with sparse regression
# 61    Molecular architecture and functional analysis of NetB, a pore-forming toxin from Clostridium perfringens
# 699   5-HTTLPR  environment interplay and its effects on neural reactivity in adolescents
# 700   Structural correlates of active-staining following magnetic resonance microscopy in the mouse brain
# 147   Hepatitis C virus NS5 inhibits mixed lineage kinase 3 to block apoptosis
# 701   Anatomical connectivity and the resting state activity of large cortical networks
# 702   Dynamic Causal Modelling of lateral interactions in the visual cortex
# 703   Complex spatiotemporal haemodynamic response following sensory stimulation in the awake rat
# 148   Cell Cycle-dependent Regulation of the Forkhead Transcription Factor FOXK2 by CDK·Cyclin Complexes
# 438   Good practice for conducting and reporting MEG research
# 704   Articulatory movements modulate auditory responses to speech
# 705   A quantitative meta-analysis and review of motor learning in the human brain
# 706   Network discovery with large DCMs
# 707   Network reconfiguration and working memory impairment in mesial temporal lobe epilepsy
# 708   Investigating the need of triggering the acquisition for infant diffusion MRI: A quantitative study including bootstrap statistics
# 709   Early visual learning induces long-lasting connectivity changes during rest in the human brain
# 710   Movement related dynamics of subthalmo-cortical alpha connectivity in Parkinson's Disease
# 711   A multivariate method to determine the dimensionality of neural representation from population activity
# 712   The impact of post-processing on spinal cord diffusion tensor imaging
# 713   Functional Specialization and Generalization for Grouping of Stimuli Based on Colour and Motion
# 77    ca2+ signalling through catsper and ca2+ stores regulate different behaviours in human sperm
# 714   Auditory Modulation of Visual Stimulus Encoding in Human Retinotopic Cortex
# 715   Set-level threshold-free tests on the intrinsic volumes of SPMs
#
#         cost
# 1469  122.0
# 1471  215.0
# 16    266.0
# 1472  330.0
# 161   381.0
# 1304  390.0
# 1473  425.0
# 1305  443.0
# 1474  534.0
# 1240  710.0
# 1254  710.0
# 1475  741.0
# 1476  747.0
# 1477  773.0
# 1293  795.0
# 1294  809.0
# 1295  819.0
# 1478  826.0
# 1479  826.0
# 1480  826.0
# 1481  826.0
# 1482  826.0
# 1483  826.0
# 1484  826.0
# 1485  826.0
# 1486  826.0
# 1487  826.0
# 1488  826.0
# 1489  826.0
# 1490  826.0
# ...     ...
# 694   1961.0
# 145   2003.0
# 146   2032.0
# 695   2101.0
# 696   2119.0
# 697   2143.0
# 1149  2184.0
# 698   2224.0
# 61    2260.0
# 699   2280.0
# 700   2298.0
# 147   2312.0
# 701   2314.0
# 702   2326.0
# 703   2344.0
# 148   2345.0
# 438   2345.0
# 704   2383.0
# 705   2385.0
# 706   2395.0
# 707   2396.0
# 708   2397.0
# 709   2421.0
# 710   2432.0
# 711   2446.0
# 712   2466.0
# 713   2484.0
# 77    2501.0
# 714   2503.0
# 715   2503.0
#
# [340 rows x 4 columns]

# %% [markdown]
# ## Task #2: Calculate mean, median, and standard deviation of cost per article for each journal.

# %%
top5_journals = pd.Series(['journal of biological chemistry',
                          'nucleic acids research',
                          'neuroimage',
                          'plos genetics',
                          'plos one'])

article_count = top_journals.groupby('journal_title')['article_title'].count()
article_mean = top_journals.groupby('journal_title')['cost'].mean()
article_median = top_journals.groupby('journal_title')['cost'].median()
article_std = top_journals.groupby('journal_title')['cost'].std()

# %%
article_stats = pd.DataFrame()
article_stats = article_stats.assign(journals=top5_journals.values)
article_stats = article_stats.assign(num_articles=article_count.values)
article_stats = article_stats.assign(mean_cost=article_mean.values)
article_stats = article_stats.assign(median_cost=article_median.values)
article_stats = article_stats.assign(std_cost=article_std.values)
article_stats
# Out:
#                           journals  num_articles    mean_cost  median_cost  \
# 0  journal of biological chemistry  62            1388.870968  1302.5
# 1  nucleic acids research           29            2215.137931  2326.0
# 2  neuroimage                       29            1162.344828  852.0
# 3  plos genetics                    22            1643.045455  1712.5
# 4  plos one                         198           934.994949   897.0
#
#      std_cost
# 0  409.846652
# 1  266.540231
# 2  442.150934
# 3  153.490337
# 4  194.968083

# %%
article_stats['mean_article_cost'] = article_stats['mean_cost']/article_stats['num_articles']
article_stats['median_article_cost'] = article_stats['median_cost']/article_stats['num_articles']
article_stats['std_article_cost'] = article_stats['std_cost']/article_stats['num_articles']

# %%
article_stats
# Out:
#                           journals  num_articles    mean_cost  median_cost  \
# 0  journal of biological chemistry  62            1388.870968  1302.5
# 1  nucleic acids research           29            2215.137931  2326.0
# 2  neuroimage                       29            1162.344828  852.0
# 3  plos genetics                    22            1643.045455  1712.5
# 4  plos one                         198           934.994949   897.0
#
#      std_cost  mean_article_cost  median_article_cost  std_article_cost
# 0  409.846652  22.401145          21.008065            6.610430
# 1  266.540231  76.384067          80.206897            9.191042
# 2  442.150934  40.080856          29.379310            15.246584
# 3  153.490337  74.683884          77.840909            6.976833
# 4  194.968083  4.722197           4.530303             0.984687
